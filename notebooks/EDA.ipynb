# %% [markdown]
# # Exploratory Data Analysis
#
# ---
# Steps taken :
# 1. Import packages
# 2. Data loading
# 3. Descriptive statisitcs and visualization
#
#
# ---

# %%
#Installing necessary libraries and packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set(color_codes=True)

# %%
#reading the dataset through pandas

client_df = pd.read_csv("../Datasets/client_data.csv")

# %% [markdown]
# ## Analyzing the client dataset for gaining insights on data fields and distribution.

# %%
client_df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
client_df.shape
# Out:
# (14606, 26)

# %%
client_df.isnull().sum()
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
#extracting the numeric columns to analyze the distributions and further relationships among fields.
client_numeric = client_df.select_dtypes(include="number")
client_numeric.head()
# Out:
#    cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# 0         0         54946                0               0.00
# 1      4660             0                0             189.95
# 2       544             0                0              47.96
# 3      1584             0                0             240.04
# 4      4425             0              526             445.75
#
#    forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# 0                   0                       0.0                     1.78
# 1                   0                       0.0                    16.27
# 2                   0                       0.0                    38.72
# 3                   0                       0.0                    19.83
# 4                 526                       0.0                   131.73
#
#    forecast_price_energy_off_peak  forecast_price_energy_peak  \
# 0                        0.114481                    0.098142
# ...

# %%
client_numeric.shape
# Out:
# (14606, 18)

# %% [markdown]
# ### 18 columns out of the 26 columns have numeric type. Visualization of distributions will provide a better insight.

# %%
num_cols = client_numeric.shape[1]
cols = 3
rows = (num_cols + cols - 1)//cols

fig, axes = plt.subplots(rows, cols, figsize=(15, 4 * rows))
axes = axes.flatten()  

for i, col in enumerate(client_numeric.columns):
    axes[i].hist(client_numeric[col].dropna(), bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Frequency")

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### The above visualization shows that the consumption data is heavily skewed since a large chunk of customers have a particular type of consumption.

# %%
skewness = client_numeric.skew().sort_values(ascending=False)
print(skewness)
# Out:
# net_margin                        36.569515
# forecast_cons_year                16.587990
# imp_cons                          13.198799
# cons_gas_12m                       9.597530
# nb_prod_act                        8.636878
# forecast_cons_12m                  7.155853
# cons_last_month                    6.391407
# cons_12m                           5.997308
# pow_max                            5.786785
# forecast_discount_energy           5.155098
# margin_net_pow_ele                 4.473326
# margin_gross_pow_ele               4.472632
# churn                              2.720715
# forecast_meter_rent_12m            1.505148
# num_years_antig                    1.446214
# forecast_price_energy_peak        -0.014331
# forecast_price_energy_off_peak    -0.119586
# forecast_price_pow_off_peak       -4.998772
# dtype: float64

# %% [markdown]
# ### Visualizing the correlation for better understanding of the relationships among variables.

# %%
corr_matrix = client_numeric.corr()
plt.figure(figsize=(10, 8))

sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5, annot_kws={"size": 8})

plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %% [markdown]
# ### Grouping data by categorical fields to understand the existing segmentations if any.

# %%
client_categorical = client_df.select_dtypes(include='object')
client_categorical.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    date_activ    date_end date_modif_prod date_renewal has_gas  \
# 0  2013-06-15  2016-06-15      2015-11-01   2015-06-23       t
# 1  2009-08-21  2016-08-30      2009-08-21   2015-08-31       f
# 2  2010-04-16  2016-04-16      2010-04-16   2015-04-17       f
# 3  2010-03-30  2016-03-30      2010-03-30   2015-03-31       f
# 4  2010-01-13  2016-03-07      2010-01-13   2015-03-09       f
#
#                           origin_up
# 0  lxidpiddsbxsbosboudacockeimpuepw
# 1  kamkkxfxxuwbdslkwifmmcsiusiuosws
# 2  kamkkxfxxuwbdslkwifmmcsiusiuosws
# ...

# %%
#checking unique values
client_categorical.nunique()
# Out:
# id                 14606
# channel_sales          8
# date_activ          1796
# date_end             368
# date_modif_prod     2129
# date_renewal         386
# has_gas                2
# origin_up              6
# dtype: int64

# %%
#Creating a copy of the original dataframe for data augmentation/feature engineering.
client_data = client_df.copy()

# %%
client_data['cons_12m'].describe()
# Out:
# count    1.460600e+04
# mean     1.592203e+05
# std      5.734653e+05
# min      0.000000e+00
# 25%      5.674750e+03
# 50%      1.411550e+04
# 75%      4.076375e+04
# max      6.207104e+06
# Name: cons_12m, dtype: float64

# %%
client_data['cons_12m'].max()
# Out:
# np.int64(6207104)

# %%
#Dividing past 12 month consumption column into different consumption subgroups to analyze the mean churn and consumer groupings.

bins = [0, 200000, 400000, 600000, client_data['cons_12m'].max()]
labels = ['0-200k', '200k-400k', '400k-600k', '600k+']

client_data['cons_12m_group'] = pd.cut(
    client_data['cons_12m'],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# %%
grouped = client_data.groupby(['cons_12m_group', 'churn'])['id'].count().unstack().fillna(0)
grouped_percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100

print(grouped_percentage)


ax = grouped_percentage.plot(kind='bar', stacked=True, figsize=(8,6), colormap='Set2')
plt.title('Churn vs Not churned consumers by consumption group')
plt.xlabel('Consumption Group (past 12 months)')
plt.ylabel('Percentage of Customers')
plt.legend(['Not Churned', 'Churned'], title = 'Churn Status')


for i, group in enumerate(grouped_percentage.index):
    bottom = 0
    for j, status in enumerate(grouped_percentage.columns):
        percent = grouped_percentage.loc[group, status]
        if percent > 0:
            ax.text(i, bottom + percent/2, f'{percent:.1f}%', ha = 'center', va = 'center', fontsize = 9, color = 'black')
        bottom += percent



plt.tight_layout()
plt.show()
# Out:
# churn                   0          1
# cons_12m_group
# 0-200k          89.899144  10.100856
# 200k-400k       93.201133   6.798867
# 400k-600k       89.010989  10.989011
# 600k+           94.608342   5.391658

# %%
grouped_percentage_renamed = grouped_percentage.rename(columns={0: 'Not Churned', 1: 'Churned'})
grouped_renamed = grouped.rename(columns={0: 'Not Churned', 1: 'Churned'})

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))


grouped_percentage_renamed.plot(kind='bar', stacked=True, ax=axs[0], colormap='Set2')
axs[0].set_title('Churn Percentage by Consumption Group')
axs[0].set_ylabel('Percentage')
axs[0].set_xlabel('Consumption Group')


for i, group in enumerate(grouped_percentage_renamed.index):
    bottom = 0
    for status in ['Not Churned', 'Churned']:
        percent = grouped_percentage_renamed.loc[group, status]
        axs[0].text(i, bottom + percent / 2, f'{percent:.1f}%', ha='center', va='center', fontsize=9, color='black')
        bottom += percent


grouped_renamed.plot(kind='bar', stacked=True, ax=axs[1], colormap='Set2')
axs[1].set_title('Churn Count by Consumption Group')
axs[1].set_ylabel('Count')
axs[1].set_xlabel('Consumption Group')


for i, group in enumerate(grouped_renamed.index):
    bottom = 0
    for status in ['Not Churned', 'Churned']:
        count = grouped_renamed.loc[group, status]
        axs[1].text(i, bottom + count / 2, int(count), ha='center', va='center', fontsize=9, color='black')
        bottom += count

plt.tight_layout()
plt.show()

# %%
client_data.groupby('cons_12m_group')['churn'].mean()
# Out:
# cons_12m_group
# 0-200k       0.101009
# 200k-400k    0.067989
# 400k-600k    0.109890
# 600k+        0.053917
# Name: churn, dtype: float64

# %%
total_churned = client_data['churn'].sum()
total_churned
# Out:
# np.int64(1419)

# %%
churning = client_data[client_data['churn'] == 1]['cons_12m_group'].value_counts().sort_values(ascending=True)
churning
# Out:
# cons_12m_group
# 400k-600k      20
# 200k-400k      24
# 600k+          53
# 0-200k       1322
# Name: count, dtype: int64

# %% [markdown]
# ### We can interpret that high number of consumers fall under the low consumption category group which is lesser than 200k units of electricity consumed. Consequently, the proportion of churned users also lie within the same group.

# %% [markdown]
# # Visualizing churn among different groups.

# %%
def plot_stacked_bars(df, title_, size = (18,10), rot_= 0, legend_='upper right'):
    """
    Plots a stacked bar chart with annotations.
    
    """
    ax = df.plot(kind='bar', stacked = True, figsize=size, rot=rot_, title=title_)

    annotate_stacked_bars(ax, textsize=14)

    plt.legend(["Not Churned", "Churned"], loc=legend_)
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, color='white', textsize=13):
    """ Adding annotations to stacked bars """
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=color,
            size=textsize
        )

# %%
#Company churn visualization
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'Churn']
churn_total = churn.groupby(churn['Churn']).count()
churn_percentage = churn_total/churn_total.sum() * 100

plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5,5), legend_="lower right")

# %% [markdown]
# # Churn by Sales Channel

# %%
channel = client_df[['id', 'channel_sales', 'churn']]
channel = channel.groupby([channel['channel_sales'], channel['churn']])['id'].count().unstack(level=1).fillna(0)
channel_churn = (channel.div(channel.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)
plot_stacked_bars(channel_churn, "Churn by Sales Channel", (10, 5), rot_=30, legend_="upper right")

# %% [markdown]
# # Churn by consumption

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

# %%
def plot_distribution(df, column, ax, bins_=50):
    """ Plots the distribution in a stacked histogram style of churned vs retained company. """

    temp = pd.DataFrame({"Retention" : df[df['churn']==0][column],
                        "Churn":df[df['churn']==1][column]})
    
    temp[["Retention", "Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    ax.set_xlabel(column)
    ax.ticklabel_format(style='plain', axis='x')

# %%
fig, axs = plt.subplots(nrows=4, figsize=(18,25))



plot_distribution(consumption, 'cons_12m', axs[0])
plot_distribution(consumption[consumption['has_gas'] == 't'], 'cons_gas_12m', axs[1])
plot_distribution(consumption, 'cons_last_month', axs[2])
plot_distribution(consumption, 'imp_cons', axs[3])

# %% [markdown]
# ### As evident from the visualization, the distribution of the consumption is highly skewed, implying the presence of outliers. Plotting boxplots to better check the outliers.

# %%
fig, axes = plt.subplots(nrows=4, figsize=(18, 25))

sns.boxplot(x=consumption['cons_12m'], ax=axes[0])
sns.boxplot(x=consumption[consumption['has_gas'] == 't']['cons_gas_12m'], ax=axes[1])
sns.boxplot(x=consumption['cons_last_month'], ax=axes[2])
sns.boxplot(x=consumption['imp_cons'], ax=axes[3])

axs[0].set_xlim(-200000, 2000000)
axs[1].set_xlim(-200000, 2000000)
axs[2].set_xlim(-20000, 100000)
# Out:
# (-20000.0, 100000.0)

# %% [markdown]
# # Visualizing forecast columns

# %%
forecast = client_df[
    ["id", "forecast_cons_12m",
    "forecast_cons_year","forecast_discount_energy","forecast_meter_rent_12m",
    "forecast_price_energy_off_peak","forecast_price_energy_peak",
    "forecast_price_pow_off_peak","churn"
    ]
]

# %%
fig, axs = plt.subplots(nrows=7, figsize=(18,50))


plot_distribution(client_df, "forecast_cons_12m", axs[0])
plot_distribution(client_df, "forecast_cons_year", axs[1])
plot_distribution(client_df, "forecast_discount_energy", axs[2])
plot_distribution(client_df, "forecast_meter_rent_12m", axs[3])
plot_distribution(client_df, "forecast_price_energy_off_peak", axs[4])
plot_distribution(client_df, "forecast_price_energy_peak", axs[5])
plot_distribution(client_df, "forecast_price_pow_off_peak", axs[6])

# %% [markdown]
# ### Visualizing contract type distributions

# %%
contract_type = client_df[['id', 'has_gas', 'churn']]
contract = contract_type.groupby([contract_type['churn'], contract_type['has_gas']])['id'].count().unstack(level=0)
contract_percentage = (contract.div(contract.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(contract_percentage, 'Contract type (with gas)')

# %% [markdown]
# ### Visualizing other column distributions

# %%
#Margins
margin = client_df[['id', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'net_margin']]
fig, axs = plt.subplots(nrows=3, figsize=(18,20))
# Plot histogram
sns.boxplot(margin["margin_gross_pow_ele"], ax=axs[0])
sns.boxplot(margin["margin_net_pow_ele"],ax=axs[1])
sns.boxplot(margin["net_margin"], ax=axs[2])

plt.show()

# %%
# Subscribed Power
power = client_df[['id', 'pow_max', 'churn']]
fig, axs = plt.subplots(nrows=1, figsize=(18, 10))
plot_distribution(power, 'pow_max', axs)

# %%
others = client_df[['id', 'nb_prod_act', 'num_years_antig', 'origin_up', 'churn']]
products = others.groupby([others["nb_prod_act"],others["churn"]])["id"].count().unstack(level=1)
products_percentage = (products.div(products.sum(axis=1), axis=0)*100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(products_percentage, "Number of products")

# %%
years_antig = others.groupby([others["num_years_antig"],others["churn"]])["id"].count().unstack(level=1)
years_antig_percentage = (years_antig.div(years_antig.sum(axis=1), axis=0)*100).sort_values(by=[1], ascending=False)
plot_stacked_bars(years_antig_percentage, "Number years")

# %%
origin = others.groupby([others["origin_up"],others["churn"]])["id"].count().unstack(level=1)
origin_percentage = (origin.div(origin.sum(axis=1), axis=0)*100).sort_values(by=[1], ascending=False)
plot_stacked_bars(origin_percentage, "Origin contract/offer")
